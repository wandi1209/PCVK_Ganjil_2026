# %% [markdown]
# # Modul 1 - Praktikum D1

# %% [markdown]
# Notebook ini hanya memuat bagian coding dari D1: penggunaan cell Markdown dan Code pada Python Notebook/Google Colab. Bagian membuat akun GitHub dan setup repository tidak ditulis ulang.

# %% [markdown]
# ## Identitas Praktikum

# %% [markdown]
# Praktikum: Pengolahan Citra dan Visi Komputer

# %% [markdown]
# Modul: 1 - Pengantar Citra Digital dan Visi Komputer

# %% [markdown]
# Bagian: D1 - Pengenalan GitHub dan Google Colab

# %% [markdown]
# ## Cek Runtime Python

# %%
import platform
import sys
print('Python version:', sys.version)
print('Platform:', platform.platform())

# %% [markdown]
# ## Cek Environment Google Colab

# %%
try:
    import google.colab
    print('Notebook berjalan di Google Colab')
except Exception:
    print('Notebook tidak berjalan di Google Colab')

# %% [markdown]
# ## Cek Library Dasar untuk Praktikum Citra

# %%
libraries = ['numpy', 'matplotlib', 'cv2', 'skimage', 'PIL', 'pandas']
for library in libraries:
    try:
        module = __import__(library)
        version = getattr(module, '__version__', 'version tidak tersedia')
        print(f'{library}: tersedia ({version})')
    except Exception as error:
        print(f'{library}: belum tersedia ({error})')

# %% [markdown]
# ## Contoh Cell Code Sederhana

# %%
nama_praktikum = 'Pengolahan Citra dan Visi Komputer'
modul = 1
bagian = 'D1'
print(f'{nama_praktikum} - Modul {modul} - Praktikum {bagian}')

# %% [markdown]
# ## Contoh Output Array sebagai Dasar Citra Digital

# %%
import numpy as np
contoh_citra_grayscale = np.array([
    [0, 64, 128],
    [32, 160, 224],
    [255, 192, 96]
], dtype=np.uint8)
print(contoh_citra_grayscale)
print('Shape:', contoh_citra_grayscale.shape)
print('Tipe data:', contoh_citra_grayscale.dtype)
